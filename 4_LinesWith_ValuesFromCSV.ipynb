# %%
'''
@Author:Shivam Mathur
@Date:2021-07-14
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-14
@Title:Write a Python program to draw line charts of the financial data of Alphabet Inc. between
October 3, 2016 to October 7, 2016.
'''

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataFrame=pd.read_csv('4_CSV.csv',sep=',',parse_dates=True,index_col=0)

# %%
dataFrame
# Out:
#                   Open        High         Low       Close
# Date
# 2016-03-10  774.250000  776.065002  769.500000  772.559998
# 2016-04-10  776.030029  778.710022  772.890015  776.429993
# 2016-05-10  779.309998  782.070007  775.650024  776.469971
# 2016-06-10  779.000000  780.479980  775.539978  776.859985
# 2016-07-10  779.659973  779.659973  770.750000  775.080017

# %%
dataFrame.plot()
plt.show()
