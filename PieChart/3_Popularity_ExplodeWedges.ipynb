# %%
'''
@Author:Shivam Mathur
@Date:2021-07-15
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-15
@Title:Write a Python programming to create a pie chart with a title of the popularity of programming Languages. Make multiple wedges of the pie.
'''

# %%
'''
Sample data:
Programming languages: Java, Python, PHP, JavaScript, C#, C++
Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
'''

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
slices=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
labels=['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
explode=(0.1,0,0,0,0,0)

# %%
plt.pie(slices,labels=labels,wedgeprops={'edgecolor':'black'},explode=explode)
plt.title('Popular Programing languanges')
plt.tight_layout()
plt.show()
