# %%
'''
@Author:Shivam Mathur
@Date:2021-07-14
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-14
@Title:Write a Python program to plot several lines with different format styles in one command
using arrays.
'''

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
growth=np.arange(1,10,1)
plt.plot(growth,growth,'rs',growth,growth**2,'bo',growth,growth**3,'gD')
plt.show()
