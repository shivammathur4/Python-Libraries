# %%
'''
@Author:Shivam Mathur
@Date:2021-07-16
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-16
@Title:Write a program to draw line and scatter plots for random 100 x and y coordinates.
'''

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.express as px

# %%
fig_ScatterPlot = px.scatter(
                            x=np.random.rand(100),
                            y=np.random.randn(100) 
                            )
fig_LinePlot=px.line(x=np.random.randn(100),
                 y=np.random.randn(100))

fig_Combined=go.Figure(data=fig_LinePlot.data+fig_ScatterPlot.data)

# %%
fig_Combined.show()
