# %%
'''
@Author:Shivam Mathur
@Date:2021-07-15
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-15
@Title:Write a Python program to draw a scatter graph taking a random distribution in X and Y and
plotted against each other.
'''

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X=np.random.randint(10,size=15)
Y=np.random.randint(10,size=15)
sizes = 100
plt.scatter(X, Y, s=sizes,edgecolor='green',facecolor='none')
plt.show()
