# %%
'''
@Author:Shivam Mathur
@Date:2021-07-16
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-16
@Title:Write a program to draw a violin plot of sex against day for a given dataset.
'''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['sex'] = df['sex'].astype('category')
df['day']=df['day'].astype('category')
cat_columns = df.select_dtypes(['category']).columns
cat_columns
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

# %%
df.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    0     No    2  Dinner     2
# 1       10.34  1.66    1     No    2  Dinner     3
# 2       21.01  3.50    1     No    2  Dinner     3
# 3       23.68  3.31    1     No    2  Dinner     2
# 4       24.59  3.61    0     No    2  Dinner     4

# %%
sns.violinplot(x=df['sex'],y=df['day'])
x_labels=['female','male']
x_values=[0,1]
y_labels=['saturday','sunday','thrusday','friday']
y_values=[1,2,3,0]
plt.xticks(x_values,x_labels)
plt.yticks(y_values,y_labels)
plt.show()
