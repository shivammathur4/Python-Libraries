# %%
'''
@Author:Shivam Mathur
@Date:2021-07-16
@Last Modified by:Shivam Mathur
@Last Modified time:2021-07-16
@Title: Write a program to draw a barplot to show count for a deck for a dataset given in the url.
'''

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe=pd.read_csv('titanic.csv')
dataframe.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
deck=dataframe['deck'].value_counts()
deck
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %%
deck_class=['A','B','C','D','E','F','G']
values=[15,47,59,33,32,13,4]

# %%
sns.barplot(x=labels,y=values)
plt.legend(['A','B','C','D','E','F','G'])
plt.show()
